# %%
import os
import numpy as np
import pandas as pd
import math
import matplotlib.pylab as plt
import seaborn as sns

# %matplotlib inline
sns.set(style='ticks', palette='Set2')

# %%
# Import data into Pandas as a data frame
df = pd.read_csv('./WBCD.csv')
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
# Transform DIAGNOSIS column to a numeric variable
df["diagnosis2"] = (df.diagnosis == "M").astype(int)
# drop the diagnosis variable expressed as 'M or 'B'
df = df.drop("diagnosis", axis="columns")
# Also, drop the ID variable as it should not be used for prediction
df = df.drop("id",axis="columns")
df.head(5)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  diagnosis2
# 0          0.4601                  0.11890           1
# 1          0.2750                  0.08902           1
# 2          0.3613                  0.08758           1
# 3          0.6638                  0.17300           1
# 4          0.2364                  0.07678           1
#
# [5 rows x 31 columns]

# %%
predictor_cols = df.loc[:, df.columns != "diagnosis2"]
target_col = df["diagnosis2"]
predictor_cols[:5]
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
from sklearn import linear_model
lin_model = linear_model.LogisticRegression(C = 100, max_iter = 2000)
# Fit the Logistic regression model now
lin_model.fit(predictor_cols, target_col)
# Out:
# C:\Users\ram\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=100, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=2000,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn import metrics

print ("Accuracy = %.2f" % (metrics.accuracy_score(lin_model.predict(predictor_cols), df.diagnosis2)))
# Out:
# Accuracy = 0.98

# %%
print(lin_model)
# Out:
# LogisticRegression(C=100, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=2000,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# col_list = list(df.columns.values.tolist())
print("Number of columns in data frame = ", len(df.columns))
count = 0
for col in df.columns:
    if(col == "diagnosis2"):
        break
    print(col,"  ", lin_model.coef_[0,count],"\n")
    count = count + 1
    
print("FINALLY printing the Intercept for Logistic Regression = ", lin_model.intercept_)
# Out:
# Number of columns in data frame =  31
# radius_mean    -4.879235971211952
#
# texture_mean    -0.1544175440557076
#
# perimeter_mean    0.32163233042146827
#
# area_mean    0.022420202068057147
#
# smoothness_mean    3.7745419783309244
#
# compactness_mean    -0.4534586451746524
#
# concavity_mean    4.44746212650926
#
# concave points_mean    6.929212035117688
#
# symmetry_mean    3.8657481115584016
#
# fractal_dimension_mean    -0.8614640781115681
#
# radius_se    -0.13163323651342754
#
# texture_se    -2.911097594967131
#
# perimeter_se    0.7389701361282537
#
# area_se    0.09448240423372155
#
# smoothness_se    0.5877214214490738
#
# compactness_se    -5.969859114396121
#
# concavity_se    -6.60720800809683
#
# concave points_se    0.5287172862542248
#
# symmetry_se    -0.8170636934223345
#
# fractal_dimension_se    -1.056835557055496
#
# radius_worst    0.5540167732065229
#
# texture_worst    0.514843785844235
#
# perimeter_worst    -0.05659947327006014
#
# area_worst    0.01261696955060492
#
# smoothness_worst    7.75927809866187
#
# compactness_worst    -3.6542268159568763
#
# concavity_worst    4.604784328108392
#
# concave points_worst    13.261977576769407
#
# symmetry_worst    6.609468721116783
#
# fractal_dimension_worst    -1.1086955171874506
#
# FINALLY printing the Intercept for Logistic Regression =  [-6.13509692]

# %%
X_new1=[[20.57,17.77,132.9,1326,0.08474,0.07864,0.0869,0.07017,0.1812,0.05667,0.5435,0.7339,3.398,74.08,0.005225,0.01308,0.0186,0.0134,0.01389,0.003532,24.99,23.41,158.8,1956,0.1238,0.1866,0.2416,0.186,0.275,0.08902]]
def Predict_for_new_patient(X_new):
    pred_val = lin_model.predict(X_new)
    print("Prediction for new value = ", pred_val)
    if(pred_val == 1):
        pred_valstr = "Malignant"
    elif(pred_val == 0):
        pred_valstr = "Benign"
        
    return(pred_valstr)
    
print("Predicted value for New Patient = " , Predict_for_new_patient(X_new1))
print("Predicted probability of class 1 (diagnosis2 = 1) = ", lin_model.predict_proba(X_new1)[:,1])
# Out:
# Prediction for new value =  [1]
# Predicted value for New Patient =  Malignant
# Predicted probability of class 1 (diagnosis2 = 1) =  [1.]

# %%
X_new2 = [[10.49,19.29,67.41,336.1,0.09989,0.08578,0.02995,0.01201,0.2217,0.06481,0.355,1.534,2.302,23.13,0.007595,0.02219,0.0288,0.008614,0.0271,0.003451,11.54,23.31,74.22,402.8,0.1219,0.1486,0.07987,0.03203,0.2826,0.07552]]
print("Prediction for new value = ", Predict_for_new_patient(X_new2))
print("Predicted probability of class 0 (or diagnosis2 = 0) = ", (1-lin_model.predict_proba(X_new2)[:,1]))
# Out:
# Prediction for new value =  [0]
# Prediction for new value =  Benign
# Predicted probability of class 0 (or diagnosis2 = 0) =  [0.99978287]

# %%
# Finally print the ODDS ratios for each of the independent variables
# The ODDS ratio os the increase in likelihood for a ONE unit increase in the independent variable
# The odds ratio is simply the exponent of the fitted coefficient
# col_list = list(df.columns.values.tolist())
print("Number of columns in data frame = ", len(df.columns))
count = 0
for col in df.columns:
    # Do nothing if you have reached the last column since it contains the diagnosis (the Y variable)
    if(col == "diagnosis2"):
        break
    print("ODDS Ratio for variable ", col,"=  ", np.exp(lin_model.coef_[0,count]),"\n")
    count = count + 1
# Out:
# Number of columns in data frame =  31
# ODDS Ratio for variable  radius_mean =   0.007602820582903093
#
# ODDS Ratio for variable  texture_mean =   0.8569141468942643
#
# ODDS Ratio for variable  perimeter_mean =   1.3793775275588644
#
# ODDS Ratio for variable  area_mean =   1.0226734236840525
#
# ODDS Ratio for variable  smoothness_mean =   43.57754428452564
#
# ODDS Ratio for variable  compactness_mean =   0.6354266314251364
#
# ODDS Ratio for variable  concavity_mean =   85.40990917088662
#
# ODDS Ratio for variable  concave points_mean =   1021.6886076184162
#
# ODDS Ratio for variable  symmetry_mean =   47.738973154565464
#
# ODDS Ratio for variable  fractal_dimension_mean =   0.42254299328332007
#
# ODDS Ratio for variable  radius_se =   0.8766624639060653
#
# ODDS Ratio for variable  texture_se =   0.05441597038410912
#
# ODDS Ratio for variable  perimeter_se =   2.0937780973441495
#
# ODDS Ratio for variable  area_se =   1.0990898236351883
#
# ODDS Ratio for variable  smoothness_se =   1.7998825656154727
#
# ODDS Ratio for variable  compactness_se =   0.0025546013001882108
#
# ODDS Ratio for variable  concavity_se =   0.001350597748182562
#
# ODDS Ratio for variable  concave points_se =   1.6967544618687358
#
# ODDS Ratio for variable  symmetry_se =   0.4417267974078994
#
# ODDS Ratio for variable  fractal_dimension_se =   0.3475538864579497
#
# ODDS Ratio for variable  radius_worst =   1.7402291034468949
#
# ODDS Ratio for variable  texture_worst =   1.6733770761916371
#
# ODDS Ratio for variable  perimeter_worst =   0.9449724803170388
#
# ODDS Ratio for variable  area_worst =   1.0126968993143197
#
# ODDS Ratio for variable  smoothness_worst =   2343.2124263701544
#
# ODDS Ratio for variable  compactness_worst =   0.02588150091252056
#
# ODDS Ratio for variable  concavity_worst =   99.96142165538788
#
# ODDS Ratio for variable  concave points_worst =   574915.054044444
#
# ODDS Ratio for variable  symmetry_worst =   742.0886579346852
#
# ODDS Ratio for variable  fractal_dimension_worst =   0.32998914559878906
